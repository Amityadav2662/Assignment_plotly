# %%
# Q1. Load the "titanic" dataset using the load_dataset function of seaborn. Use Plotly express to plot a
# scatter plot for age and fare columns in the titanic dataset.
import plotly.graph_objs as go
import seaborn as sns
titanic = sns.load_dataset("titanic")

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
fig = go.Figure(data = [go.Scatter(x=titanic.age , y=titanic.fare, mode = "markers")])
fig.show()

# %% [markdown]
# ![image.png](attachment:a31a7b3b-419e-464b-907f-0f346bca0040.png)

# %%
# Q2. Using the tips dataset in the Plotly library, plot a box plot using Plotly express.
import plotly.express as ex
tip = ex.data.tips()

# %%
tip.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
fig = ex.box(tip, x = "total_bill", y = "sex", color = "smoker")
fig.show()

# %% [markdown]
# ![image.png](attachment:b0ad4eda-ef9a-4f17-a802-b019f21323f3.png)

# %%
# Q3. Using the tips dataset in the Plotly library, Plot a histogram for x= "sex" and y="total_bill" column in
# the tips dataset. Also, use the "smoker" column with the pattern_shape parameter and the "day"
# column with the color parameter.
import plotly.express as px
tip = px.data.tips()

# %%
tip.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
fig = px.histogram(tip, x = "sex", y = "total_bill", pattern_shape = "smoker", color = "day")
fig.show()

# %% [markdown]
# ![image.png](attachment:d43ebab4-0441-48ee-b70d-6e9021206d7b.png)

# %%
# Q4. Using the iris dataset in the Plotly library, Plot a scatter matrix plot, using the "species" column for
# the color parameter.
# Note: Use "sepal_length", "sepal_width", "petal_length", "petal_width" columns only with the
# dimensions parameter.

import plotly.express as px
iris = px.data.iris()

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
fig = px.scatter_matrix(iris,
                        dimensions = ["sepal_length", "sepal_width", "petal_length", "petal_width"],
                        color = "species")
fig.show()

# %% [markdown]
# ![image.png](attachment:54dc799f-fb91-40a6-a572-53a445f8286c.png)

# %%
# Q5. What is Distplot? Using Plotly express, plot a distplot.
Ans.
A distplot is a type of plot that shows the distribution of a univariate set of data. It is
a combination of a histogram and a kernel density estimate. The histogram shows the frequency
of each value in the dataset, while the kernel density estimate shows the probability density
function of the data.

# %%
# Example of displot but in plotly have not displot attribute. so i am using histogram the
# work same as like displot.
import plotly.express as px
tip = px.data.tips()

# %%
tip.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
fig = px.histogram(tip, x = "total_bill", y = "tip")
fig.show()

# %% [markdown]
# ![image.png](attachment:07fb1cc3-b434-4af0-b9fc-1706641a44dc.png)
